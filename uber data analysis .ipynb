# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
dataset=pd.read_csv('UberDataset.csv')

# %%
dataset
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
dataset.shape
# Out:
# (1156, 7)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# # Data preprocessing

# %%
dataset['PURPOSE*'].fillna("NOT",inplace=True)

# %%
dataset.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NOT
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
dataset['START_DATE*']=pd.to_datetime(dataset['START_DATE*'],errors='coerce') 

dataset['END_DATE*']=pd.to_datetime(dataset['END_DATE*'],errors='coerce')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   datetime64[ns]
#  1   END_DATE*    1155 non-null   datetime64[ns]
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     1156 non-null   object
#  7   END*_DATE*   1155 non-null   datetime64[ns]
# dtypes: datetime64[ns](3), float64(1), object(4)
# memory usage: 72.4+ KB

# %%
from datetime import datetime 
dataset['date']=pd.DatetimeIndex(dataset['START_DATE*']).date
dataset['time']=pd.DatetimeIndex(dataset['START_DATE*']).hour

# %%
dataset.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES*         PURPOSE*          END*_DATE*        date  \
# 0      Fort Pierce     5.1   Meal/Entertain 2016-01-01 21:17:00  2016-01-01
# 1      Fort Pierce     5.0              NOT 2016-01-02 01:37:00  2016-01-02
# 2      Fort Pierce     4.8  Errand/Supplies 2016-01-02 20:38:00  2016-01-02
# 3      Fort Pierce     4.7          Meeting 2016-01-05 17:45:00  2016-01-05
# 4  West Palm Beach    63.7   Customer Visit 2016-01-06 15:49:00  2016-01-06
#
#    time
# 0  21.0
# 1   1.0
# 2  20.0
# 3  17.0
# 4  14.0

# %%
dataset['day-night'] = pd.cut(x=dataset['time'],bins=[0,10,15,19,24],labels=['Morning','Afternoon','Evening','Night'])

# %%
dataset.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES*         PURPOSE*          END*_DATE*        date  \
# 0      Fort Pierce     5.1   Meal/Entertain 2016-01-01 21:17:00  2016-01-01
# 1      Fort Pierce     5.0              NOT 2016-01-02 01:37:00  2016-01-02
# 2      Fort Pierce     4.8  Errand/Supplies 2016-01-02 20:38:00  2016-01-02
# 3      Fort Pierce     4.7          Meeting 2016-01-05 17:45:00  2016-01-05
# 4  West Palm Beach    63.7   Customer Visit 2016-01-06 15:49:00  2016-01-06
#
#    time  day-night
# 0  21.0      Night
# 1   1.0    Morning
# 2  20.0      Night
# 3  17.0    Evening
# ...

# %%
dataset.dropna(inplace=True)

# %%
dataset.shape
# Out:
# (1136, 11)

# %% [markdown]
# # Data Visulization

# %%
plt.figure(figsize=(20, 5))
plt.subplot(1, 2, 1)
sns.countplot(y=dataset['CATEGORY*'])
plt.xticks(rotation=90)
plt.subplot(1, 2, 2)
sns.countplot(y=dataset['PURPOSE*'])
# Out:
# <Axes: xlabel='count', ylabel='PURPOSE*'>

# %%
sns.countplot(y=dataset['day-night'])
# Out:
# <Axes: xlabel='count', ylabel='day-night'>

# %%
dataset.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES*         PURPOSE*          END*_DATE*        date  \
# 0      Fort Pierce     5.1   Meal/Entertain 2016-01-01 21:17:00  2016-01-01
# 1      Fort Pierce     5.0              NOT 2016-01-02 01:37:00  2016-01-02
# 2      Fort Pierce     4.8  Errand/Supplies 2016-01-02 20:38:00  2016-01-02
# 3      Fort Pierce     4.7          Meeting 2016-01-05 17:45:00  2016-01-05
# 4  West Palm Beach    63.7   Customer Visit 2016-01-06 15:49:00  2016-01-06
#
#    time  day-night
# 0  21.0      Night
# 1   1.0    Morning
# 2  20.0      Night
# 3  17.0    Evening
# ...

# %%
dataset['MONTH']=pd.DatetimeIndex(dataset['START_DATE*']).month#start date se month extrat karta hai.


month_label = {1.0:'Jan',2.0:'Feb',3.0:'Mar',4.0:'April',
               5.0:'May',6.0:'June',7.0:'July',8.0:'Aug',
               9.0:'Sep',10.0:'Oct',11.0:'Nov',12.0:'Dec'}#month ko starting names assign karta hai.
dataset['MONTH']=dataset.MONTH.map(month_label)#number months ko string names se replace karna hai.

mon=dataset.MONTH.value_counts(sort=False)#Har month ke counts calculate karta hai.

# %%
dataset.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES*         PURPOSE*          END*_DATE*        date  \
# 0      Fort Pierce     5.1   Meal/Entertain 2016-01-01 21:17:00  2016-01-01
# 1      Fort Pierce     5.0              NOT 2016-01-02 01:37:00  2016-01-02
# 2      Fort Pierce     4.8  Errand/Supplies 2016-01-02 20:38:00  2016-01-02
# 3      Fort Pierce     4.7          Meeting 2016-01-05 17:45:00  2016-01-05
# 4  West Palm Beach    63.7   Customer Visit 2016-01-06 15:49:00  2016-01-06
#
#    time  day-night MONTH
# 0  21.0      Night   Jan
# 1   1.0    Morning   Jan
# 2  20.0      Night   Jan
# ...

# %%
df = pd.DataFrame({
    "MONTHS": mon.values, #har month ka total count.
    "VALUE COUNT":dataset.groupby('MONTH',sort=False)['MILES*'].max()#har month ke max miles ka value.

})

p=sns.lineplot(data=df)#line plot banta hai.
p.set(xlabel="MONTHS",ylabel="VALUE COUNT")
# Out:
# [Text(0.5, 0, 'MONTHS'), Text(0, 0.5, 'VALUE COUNT')]

# %%
dataset.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES*         PURPOSE*          END*_DATE*        date  \
# 0      Fort Pierce     5.1   Meal/Entertain 2016-01-01 21:17:00  2016-01-01
# 1      Fort Pierce     5.0              NOT 2016-01-02 01:37:00  2016-01-02
# 2      Fort Pierce     4.8  Errand/Supplies 2016-01-02 20:38:00  2016-01-02
# 3      Fort Pierce     4.7          Meeting 2016-01-05 17:45:00  2016-01-05
# 4  West Palm Beach    63.7   Customer Visit 2016-01-06 15:49:00  2016-01-06
#
#    time  day-night MONTH
# 0  21.0      Night   Jan
# 1   1.0    Morning   Jan
# 2  20.0      Night   Jan
# ...

# %%
dataset['DAY'] = dataset['START_DATE*'].dt.weekday

day_label = {0: 'Mon', 1: 'Tues', 2: 'Wed', 3: 'Thur', 4: 'Fri', 5: 'Sat', 6: 'Sun'}

dataset['DAY'] = dataset['DAY'].map(day_label)

# %%
dataset.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES*         PURPOSE*          END*_DATE*        date  \
# 0      Fort Pierce     5.1   Meal/Entertain 2016-01-01 21:17:00  2016-01-01
# 1      Fort Pierce     5.0              NOT 2016-01-02 01:37:00  2016-01-02
# 2      Fort Pierce     4.8  Errand/Supplies 2016-01-02 20:38:00  2016-01-02
# 3      Fort Pierce     4.7          Meeting 2016-01-05 17:45:00  2016-01-05
# 4  West Palm Beach    63.7   Customer Visit 2016-01-06 15:49:00  2016-01-06
#
#    time  day-night MONTH   DAY
# 0  21.0      Night   Jan   Fri
# 1   1.0    Morning   Jan   Sat
# ...

# %%
day_label=dataset.DAY.value_counts()
sns.barplot(x=day_label.index,y=day_label)
plt.xlabel('DAY')
plt.ylabel('COUNT')
# Out:
# Text(0, 0.5, 'COUNT')

# %%
dataset.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*       START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#              STOP*  MILES*         PURPOSE*          END*_DATE*        date  \
# 0      Fort Pierce     5.1   Meal/Entertain 2016-01-01 21:17:00  2016-01-01
# 1      Fort Pierce     5.0              NOT 2016-01-02 01:37:00  2016-01-02
# 2      Fort Pierce     4.8  Errand/Supplies 2016-01-02 20:38:00  2016-01-02
# 3      Fort Pierce     4.7          Meeting 2016-01-05 17:45:00  2016-01-05
# 4  West Palm Beach    63.7   Customer Visit 2016-01-06 15:49:00  2016-01-06
#
#    time  day-night MONTH   DAY
# 0  21.0      Night   Jan   Fri
# 1   1.0    Morning   Jan   Sat
# ...

# %%
sns.boxplot(y=dataset['MILES*'])
# Out:
# <Axes: ylabel='MILES*'>

# %%
sns.boxplot(y=dataset[dataset['MILES*']<100]['MILES*'])
# Out:
# <Axes: ylabel='MILES*'>

# %%
sns.boxplot(y=dataset[dataset['MILES*']<40]['MILES*'])
# Out:
# <Axes: ylabel='MILES*'>

# %%
sns.distplot(dataset[dataset['MILES*']<40]['MILES*'])
# Out:
# C:\Users\NAIK LOKESH\AppData\Local\Temp\ipykernel_14528\564126997.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset[dataset['MILES*']<40]['MILES*'])
# <Axes: xlabel='MILES*', ylabel='Density'>
